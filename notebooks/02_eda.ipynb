# %% [markdown]
# # Notebook 02: Exploratory Data Analysis & Quality Audit
# Analyzes transaction volumes, cancellations, negative quantities, invalid prices, and revenue distributions.

# %%
import sys
sys.path.append('..')
from src.ingestion.loader import load_raw_data
from src.cleaning.cleaner import clean_transaction_data

raw_df = load_raw_data()
df_clean, summary = clean_transaction_data(raw_df)
print('Data Quality Audit Summary:')
for k, v in summary.items():
    print(f' - {k}: {v}')

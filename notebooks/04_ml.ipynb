# %% [markdown]
# # Notebook 04: Machine Learning & Customer Churn Modeling
# Trains and benchmarks Logistic Regression, Random Forest, and Gradient Boosting churn models.

# %%
import sys
sys.path.append('..')
from src.ingestion.loader import load_raw_data
from src.cleaning.cleaner import clean_transaction_data
from src.ml.churn_model import train_churn_prediction_model

df_clean, _ = clean_transaction_data(load_raw_data())
res = train_churn_prediction_model(df_clean)
print('Best Churn Predictor:', res['best_model_name'])
res['model_metrics']

# %% [markdown]
# # Notebook 05: Revenue Time-Series Forecasting
# Benchmarks Naive Baseline, Holt-Winters Exponential Smoothing, and SARIMA models.

# %%
import sys
sys.path.append('..')
from src.ingestion.loader import load_raw_data
from src.cleaning.cleaner import clean_transaction_data
from src.forecasting.revenue_forecast import forecast_monthly_revenue

df_clean, _ = clean_transaction_data(load_raw_data())
forecast_res = forecast_monthly_revenue(df_clean)
print('Best Forecast Model:', forecast_res['best_model_name'])
forecast_res['evaluations']

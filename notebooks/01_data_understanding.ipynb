# %% [markdown]
# # Notebook 01: Raw Data Understanding & Ingestion Inspection
# This notebook inspects the official UCI Online Retail II raw dataset (~1 million transaction records).

# %%
import sys
sys.path.append('..')
from src.ingestion.loader import load_raw_data

df_raw = load_raw_data()
print('Raw Dataset Shape:', df_raw.shape)
df_raw.head()
